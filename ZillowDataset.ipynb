# %%
# Import Dependencies
import pandas as pd

# %%
Zillow_values = "Resources/Zillow_values.csv"
Zillow2023 = "Resources/AZZillow2023.csv"

# %%
Zillow_values_df = pd.read_csv(Zillow_values)
Zillow2023_df = pd.read_csv(Zillow2023)

# %%
Zillow_values_df.head(10)
# Out:
#    Zipcode  Zillow_value_per_Zip
# 0    85003           584908.2331
# 1    85004           445080.8570
# 2    85006           418856.7727
# 3    85007           414950.5322
# 4    85008           364850.4607
# 5    85009           285493.7243
# 6    85012           668437.4812
# 7    85013           486583.8996
# 8    85014           434795.7069
# 9    85015           347868.1627

# %%
Zillow2023_df.head(12)
# Out:
#     Unnamed: 0  Zipcode  Zillow_value_per_Zip State        City  \
# 0          296    85383           646945.8074    AZ      Peoria
# 1          429    85928           439371.3260    AZ       Heber
# 2          154    85249           662463.1264    AZ    Chandler
# 3          398    85741           324449.9377    AZ      Tucson
# 4          447    86305           701274.6021    AZ    Prescott
# 5          181    85260           676715.3485    AZ  Scottsdale
# 6          427    85901           412723.1306    AZ    Show Low
# 7           28    85027           384826.5768    AZ     Phoenix
# 8          403    85743           401822.9489    AZ      Tucson
# 9          268    85367           326992.6633    AZ        Yuma
# 10         393    85735           335049.8903    AZ      Tucson
# 11         423    85757           323033.9758    AZ      Tucson
#
#               Street  Bedroom  Bathroom  Area        PPSq   LotArea  \
# 0    W Red Range Way        4       2.0  1311   49.580473  2.350000
# 1           Aspen Ln        2       1.0   872  143.348624  0.040000
# 2      E Victoria St        3       2.0  1056  132.575758  0.164141
# 3     W Firebrook Rd        2       2.0  1020  139.215686  0.140000
# 4            Bear Dr        3       2.0  1215  148.148148  0.170000
# 5   E Charter Oak Dr        3       2.0  1008  193.452381  0.135147
# 6   Lone Pine Dam Rd        2       1.0  1196  167.140468  0.110000
# 7        W Topeka Dr        3       2.0  1063  206.020696  0.192746
# 8    W Summer Sun Ln        3       1.0  1008  217.757936  1.730000
# 9          E 54th Dr        3       1.0   900  248.888889  0.120000
# 10     S Postvale Rd        3       2.0  1869  120.117710  0.400000
# 11     W Jadewood Ln        3       2.0  1195  188.284519  0.190000
#
#      Latitude   Longitude  ListedPrice      PriceTier
# 0   35.050457 -114.229410        65000  less than 250
# 1   33.391224 -110.780920       125000  less than 250
# 2   32.678486 -114.630070       140000  less than 250
# 3   32.720356 -110.643040       142000  less than 250
# 4   32.816208 -109.721275       180000  less than 250
# 5   32.708180 -114.678690       195000  less than 250
# 6   33.394638 -110.777500       199900  less than 250
# 7   31.563510 -110.301450       219000  less than 250
# 8   31.459599 -111.012924       219500  less than 250
# 9   32.201020 -110.911270       224000  less than 250
# 10  31.680025 -109.687590       224500  less than 250
# 11  34.860160 -114.600290       225000  less than 250

# %%
Zillow = pd.merge(Zillow_values_df, Zillow2023_df, on='Zipcode', how='inner')
Zillow.head(13)
# Out:
#     Zipcode  Zillow_value_per_Zip_x  Unnamed: 0  Zillow_value_per_Zip_y State  \
# 0     85006             418856.7727           0             418856.7727    AZ
# 1     85007             414950.5322           1             414950.5322    AZ
# 2     85009             285493.7243           2             285493.7243    AZ
# 3     85012             668437.4812           3             668437.4812    AZ
# 4     85013             486583.8996           4             486583.8996    AZ
# 5     85014             434795.7069           8             434795.7069    AZ
# 6     85014             434795.7069           7             434795.7069    AZ
# 7     85014             434795.7069           5             434795.7069    AZ
# 8     85014             434795.7069           9             434795.7069    AZ
# 9     85014             434795.7069           6             434795.7069    AZ
# 10    85015             347868.1627          10             347868.1627    AZ
# 11    85016             507496.7530          11             507496.7530    AZ
# 12    85017             310600.5399          12             310600.5399    AZ
#
#        City          Street  Bedroom  Bathroom  Area        PPSq   LotArea  \
# 0   Phoenix     N Dayton St        2       2.0  1855  256.064690  0.145087
# 1   Phoenix    W Lynwood St        2       3.0  2423  531.985142  0.980000
# 2   Phoenix  W Virginia Ave        4       2.0  1706  199.296014  0.280000
# 3   Phoenix     E Tuckey Ln        4       3.0  2827  256.455607  0.175000
# 4   Phoenix      W Roma Ave        1       1.0   704  383.522727  0.670000
# 5   Phoenix  N Longview Ave        2       2.0  1120  302.678571  0.230000
# 6   Phoenix  N Longview Ave        5       2.0  2040  188.725490  0.099977
# 7   Phoenix       N 13th Pl        3       2.0  1454  299.105915  0.108081
# 8   Phoenix      N 10th Way        5       3.0  3058  359.712230  0.290000
# 9   Phoenix   E Ocotillo Rd        6       6.0  6429  699.953336  0.471166
# 10  Phoenix   W Whitton Ave        4       2.0  2260  210.176991  0.170000
# 11  Phoenix    E Weldon Ave        4       5.0  4518  265.604250  0.940000
# 12  Phoenix   W Solano Dr S        2       3.0  1612  325.682382  1.030000
#
#      Latitude   Longitude  ListedPrice                   PriceTier
# 0   33.071648 -111.454926       475000         between 451 and 500
# 1   34.590916 -112.444150      1289000        between 1.25 and 1.5
# 2   32.194954 -110.870460       339999         between 301 and 350
# 3   33.448963 -111.671280       725000         between 701 and 750
# 4   34.731953 -111.995346       270000         between 251 and 300
# 5   34.516693 -114.299500       339000         between 301 and 350
# 6   33.397583 -111.752014       385000         between 351 and 400
# 7   33.850014 -112.096750       434900         between 401 and 450
# 8   34.490780 -114.342155      1100000  between a million and 1.25
# 9   35.159450 -111.634120      4500000           between 4 and 4.5
# 10  32.377716 -111.125870       475000         between 451 and 500
# 11  32.320312 -110.945950      1200000  between a million and 1.25
# 12  32.282710 -110.888610       525000         between 501 and 550

# %%
Zillow.to_csv("Zillow.csv")
