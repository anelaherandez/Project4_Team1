# %%
# Import Dependencies
import pandas as pd

# %%
Zillow_values = "Resources/Zillow_values.csv"
Zillow2023 = "Resources/AZZillow2023.csv"

# %%
Zillow_values_df = pd.read_csv(Zillow_values)
Zillow2023_df = pd.read_csv(Zillow2023)

# %%
Zillow_values_df.head(10)
# Out:
#    Zipcode  Zillow_value_per_Zip
# 0    85003           584908.2331
# 1    85004           445080.8570
# 2    85006           418856.7727
# 3    85007           414950.5322
# 4    85008           364850.4607
# 5    85009           285493.7243
# 6    85012           668437.4812
# 7    85013           486583.8996
# 8    85014           434795.7069
# 9    85015           347868.1627

# %%
Zillow2023_df.head(12)
# Out:
#     Zipcode State        City            Street  Bedroom  Bathroom  Area  \
# 0     85383    AZ      Peoria   W Red Range Way        4       2.0  1311
# 1     85928    AZ       Heber          Aspen Ln        2       1.0   872
# 2     85249    AZ    Chandler     E Victoria St        3       2.0  1056
# 3     85741    AZ      Tucson    W Firebrook Rd        2       2.0  1020
# 4     86305    AZ    Prescott           Bear Dr        3       2.0  1215
# 5     85260    AZ  Scottsdale  E Charter Oak Dr        3       2.0  1008
# 6     85901    AZ    Show Low  Lone Pine Dam Rd        2       1.0  1196
# 7     85027    AZ     Phoenix       W Topeka Dr        3       2.0  1063
# 8     85743    AZ      Tucson   W Summer Sun Ln        3       1.0  1008
# 9     85367    AZ        Yuma         E 54th Dr        3       1.0   900
# 10    85735    AZ      Tucson     S Postvale Rd        3       2.0  1869
# 11    85757    AZ      Tucson     W Jadewood Ln        3       2.0  1195
#
#           PPSq   LotArea   Latitude   Longitude  ListedPrice      PriceTier
# 0    49.580473  2.350000  35.050457 -114.229410        65000  less than 250
# 1   143.348624  0.040000  33.391224 -110.780920       125000  less than 250
# 2   132.575758  0.164141  32.678486 -114.630070       140000  less than 250
# 3   139.215686  0.140000  32.720356 -110.643040       142000  less than 250
# 4   148.148148  0.170000  32.816208 -109.721275       180000  less than 250
# 5   193.452381  0.135147  32.708180 -114.678690       195000  less than 250
# 6   167.140468  0.110000  33.394638 -110.777500       199900  less than 250
# 7   206.020696  0.192746  31.563510 -110.301450       219000  less than 250
# 8   217.757936  1.730000  31.459599 -111.012924       219500  less than 250
# 9   248.888889  0.120000  32.201020 -110.911270       224000  less than 250
# 10  120.117710  0.400000  31.680025 -109.687590       224500  less than 250
# 11  188.284519  0.190000  34.860160 -114.600290       225000  less than 250

# %%
Zillow = pd.merge(Zillow_values_df, Zillow2023_df, on='Zipcode', how='inner')
Zillow.head(13)
# Out:
#     Zipcode  Zillow_value_per_Zip State     City          Street  Bedroom  \
# 0     85006           418856.7727    AZ  Phoenix     N Dayton St        2
# 1     85007           414950.5322    AZ  Phoenix    W Lynwood St        2
# 2     85009           285493.7243    AZ  Phoenix  W Virginia Ave        4
# 3     85012           668437.4812    AZ  Phoenix     E Tuckey Ln        4
# 4     85013           486583.8996    AZ  Phoenix      W Roma Ave        1
# 5     85014           434795.7069    AZ  Phoenix  N Longview Ave        2
# 6     85014           434795.7069    AZ  Phoenix  N Longview Ave        5
# 7     85014           434795.7069    AZ  Phoenix       N 13th Pl        3
# 8     85014           434795.7069    AZ  Phoenix      N 10th Way        5
# 9     85014           434795.7069    AZ  Phoenix   E Ocotillo Rd        6
# 10    85015           347868.1627    AZ  Phoenix   W Whitton Ave        4
# 11    85016           507496.7530    AZ  Phoenix    E Weldon Ave        4
# 12    85017           310600.5399    AZ  Phoenix   W Solano Dr S        2
#
#     Bathroom  Area        PPSq   LotArea   Latitude   Longitude  ListedPrice  \
# 0        2.0  1855  256.064690  0.145087  33.071648 -111.454926       475000
# 1        3.0  2423  531.985142  0.980000  34.590916 -112.444150      1289000
# 2        2.0  1706  199.296014  0.280000  32.194954 -110.870460       339999
# 3        3.0  2827  256.455607  0.175000  33.448963 -111.671280       725000
# 4        1.0   704  383.522727  0.670000  34.731953 -111.995346       270000
# 5        2.0  1120  302.678571  0.230000  34.516693 -114.299500       339000
# 6        2.0  2040  188.725490  0.099977  33.397583 -111.752014       385000
# 7        2.0  1454  299.105915  0.108081  33.850014 -112.096750       434900
# 8        3.0  3058  359.712230  0.290000  34.490780 -114.342155      1100000
# 9        6.0  6429  699.953336  0.471166  35.159450 -111.634120      4500000
# 10       2.0  2260  210.176991  0.170000  32.377716 -111.125870       475000
# 11       5.0  4518  265.604250  0.940000  32.320312 -110.945950      1200000
# 12       3.0  1612  325.682382  1.030000  32.282710 -110.888610       525000
#
#                      PriceTier
# 0          between 451 and 500
# 1         between 1.25 and 1.5
# 2          between 301 and 350
# 3          between 701 and 750
# 4          between 251 and 300
# 5          between 301 and 350
# 6          between 351 and 400
# 7          between 401 and 450
# 8   between a million and 1.25
# 9               over 4 million
# 10         between 451 and 500
# 11  between a million and 1.25
# 12         between 501 and 550

# %%
Zillow.to_csv("Zillow.csv")
